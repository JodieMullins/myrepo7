# %%
import requests
from bs4 import BeautifulSoup
import string
import pandas as pd
from selenium import webdriver

# specify webdriver browser
driver = webdriver.Chrome()
# Out:
# C:\Users\jomuf\AppData\Local\Temp\ipykernel_31132\1926890629.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# determine a URL to start pulling from
URL = "https://books.toscrape.com/" 

# request to pull the page
page = requests.get(URL)

# javascript friendly request
jspage = driver.get(URL)

# turn results into a list
results = []

# hold entire js page content and display in its own window
jscontent = driver.page_source

# pull the page through parser 
soup = BeautifulSoup(page.content, "html.parser")


find_side_panel = soup.find_all(attrs={'class': 'side_categories'})

for element in find_side_panel:
    side_panel = element.find('li')

#for element in soup.find_all(attrs=('class': 'side_categories')):
#    category = element.find('a')

# wordsoup variable holding a list containing parsed info
#wordsoup = results.append(str(soup))

print(side_panel)
# Out:
# <li>
# <a href="catalogue/category/books_1/index.html">
#
#                                 Books
#
#                         </a>
# <ul>
# <li>
# <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>
# </li>
# <li>
# <a href="catalogue/category/books/philosophy_7/index.html">
# ...

# %%
results = soup.find(role="alert")

soup.get_text()
# Out:
# "\n\n\n\n  \n\n\n    All products | Books to Scrape - Sandbox\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nBooks to Scrape We love being scraped!\n\n\n\n\n\n\n\n\nHome\n\nAll products\n\n\n\n\n\n\n\n\n\n                            \n                                Books\n                            \n                        \n\n\n\n                            \n                                Travel\n                            \n                        \n\n\n\n                            \n                                Mystery\n                            \n                        \n\n\n\n                            \n                                Historical Fiction\n                            \n                        \n\n\n\n                            \n                                Sequential Art\n                            \n                        \n\n\n\n                            \n                                Classics\n                            \n                       
# ...

# %%
job_elements = soup.find_all("div") #, class_="div.jss-f8")



for el in job_elements:
    div = el.find('div')


print(el)
# Out:
# <div>
# <ul class="pager">
# <li class="current">
#
#                 Page 1 of 50
#
#             </li>
# <li class="next"><a href="catalogue/page-2.html">next</a></li>
# </ul>
# </div>

# %%
# Define a function named word_count that takes one argument, 'str'.
def word_count(str):
    # Create an empty dictionary named 'counts' to store word frequencies.
    counts = dict()
    
    # Split the input string 'str' into a list of words using spaces as separators and store it in the 'words' list.
    words = str.split()

    # Iterate through each word in the 'words' list.
    for word in words:
        # Check if the word is already in the 'counts' dictionary.
        if word in counts:
            # If the word is already in the dictionary, increment its frequency by 1.
            counts[word] += 1
        else:
            # If the word is not in the dictionary, add it to the dictionary with a frequency of 1.
            counts[word] = 1

    # Return the 'counts' dictionary, which contains word frequencies.
    return counts

# %%
 def remove_punctuation(input_string):
    # Make a translation table that maps all punctuation characters to None
    translator = str.maketrans("", "", string.punctuation)

    # Apply the translation table to the input string
    result = input_string.translate(translator)

    return result

entry = """Budget Analyst
Finance Remote Continental United States, Kentucky (Remote)
Position Summary

Partners for Rural Impact (PRI) is a newly formed nonprofit organization that provides deep community support for youth and their families and works to ensure success for young people from cradle to career.  The Budget Analyst provides analytical support for grant budgets and handles all budget transactions for the grant programs including monthly reconciliation of budgets and purchasing cards.  The Budget Analyst will use knowledge of PRI policies, federal regulations, and grant terms and conditions to review and examine transactions to ensure expenses are allowable, reasonable, and allocable to the grant. The Budget Analyst will analyze financial data to perform monthly and annual reporting including Reconciliation, Budget to Actual, and Federal Financial Reports, and will disseminate these reports and use historical cost analysis to assist Project Directors and staff in budgeting and future planning. 

 

Primary Duties and Responsibilities

To perform this job successfully, an individual must be able to perform each primary duty satisfactorily. The requirements of the position are representative of the knowledge, skill, and/or ability required, with regular and predictable attendance essential. Reasonable accommodations may be made to enable individuals with disabilities to perform essential functions.

 

Provides analytical support for multiple grant budgets administered by Partners for Rural Impact and meets regularly with Project Directors to provide budget projections, discuss planned costs, review available financial options, and address budgetary implications.  This includes planning for annual operational budget allocations.
Conducts training with partners and staff regarding budgetary and grant expenditure requirements
Compiles financial data and works in collaboration with the Director to prepare applicable financial reports for annual reporting purposes.
Reviews expenditures to ensure all expenses are properly documented substantiated comply with college policy and US Department of Education or other federal regulations and are applicable to the grant goals and objectives. 
Ensures accounting records of grants are reconciled with PRI financial records, and that grant allocations are appropriate, properly recorded, and adequately documented. 
Monitors federal match from partners and makes certain documented match meets federal or other guidelines for compliance.  Provides training around match requirements to partners and staff and seeks out match sources.
Uses knowledge of Federal Regulations to make recommendations to Project Directors and staff regarding allowable costs and activities.
Performs sub-recipient monitoring activities and conducts annual financial visits
Oversees departmental usage of purchasing cards (pcard) and project costs
Reviews and manages monthly travel reports from staff to make certain that reports are complete, in compliance with organizational and federal policies and turned in timely.  Provides feedback to PRI staff about travel reports and requests supporting documentation where applicable.
Develops forms, documents, and processes to support departmental compliance with federal budget management regulations
 

Position Location  Schedule

The Budget Analyst may be considered for remote and or hybrid work with periodic travel and meetings to home office located in Berea Kentucky.  

 

Normal business hours are Monday through Friday with in-office and or remote work a possibility. Because of the nature of the responsibility to schools, partners, funders, and the service region, individual offices or departments may have operating hours that extend beyond this period and may include evening and/or weekend hours.



Minimum Qualifications

Education Required

Bachelors degree in business accounting or related field
 

Experience Required

At least 2 3 years financial and or budgetary experience

Special Skills Knowledge and Abilities

Demonstrated proficiency in all Microsoft Office applications and ability to organize and analyze data 
Strong organizational skills, including time management and prioritization
Exceptional verbal and written communication skills
Banner experience preferred""" 

output = remove_punctuation(entry)

entry = entry.lower()

for punctuation in ',.?;()"-':
    entry = entry.replace(punctuation, "")

# %%
budget_analyst_position = word_count(entry)


# Call the word_count function with an input sentence and print the results.
print(budget_analyst_position)
# Out:
# {'budget': 10, 'analyst': 5, 'finance': 1, 'remote': 4, 'continental': 1, 'united': 1, 'states': 1, 'kentucky': 2, 'position': 3, 'summary': 1, 'partners': 6, 'for': 11, 'rural': 2, 'impact': 2, 'pri': 4, 'is': 1, 'a': 2, 'newly': 1, 'formed': 1, 'nonprofit': 1, 'organization': 1, 'that': 4, 'provides': 5, 'deep': 1, 'community': 1, 'support': 4, 'youth': 1, 'and': 49, 'their': 1, 'families': 1, 'works': 2, 'to': 25, 'ensure': 3, 'success': 1, 'young': 1, 'people': 1, 'from': 3, 'cradle': 1, 'career': 1, 'the': 14, 'analytical': 2, 'grant': 8, 'budgets': 3, 'handles': 1, 'all': 3, 'transactions': 2, 'programs': 1, 'including': 3, 'monthly': 3, 'reconciliation': 2, 'of': 10, 'purchasing': 2, 'cards': 2, 'will': 3, 'use': 2, 'knowledge': 4, 'policies': 2, 'federal': 8, 'regulations': 4, 'terms': 1, 'conditions': 1, 'review': 2, 'examine': 1, 'expenses': 2, 'are': 8, 'allowable': 2, 'reasonable': 2, 'allocable': 1, 'analyze': 2, 'financial': 8, 'data': 3, 'perform': 4, 'annual': 4, 'rep
# ...

# %%
budget_frame = pd.DataFrame.from_dict(budget_analyst_position, orient="index",
                                        columns=["Occurance"])

display(budget_frame)
# Out:
#                Occurance
# budget                10
# analyst                5
# finance                1
# remote                 4
# continental            1
# ...                  ...
# verbal                 1
# written                1
# communication          1
# banner                 1
# preferred              1
#
# [276 rows x 1 columns]

# %%
budget_frame_sorted = budget_frame.sort_values(by=['Occurance'], ascending=False )

display(budget_frame_sorted[6:36])
# Out:
#              Occurance
# budget              10
# financial            8
# are                  8
# federal              8
# grant                8
# or                   7
# in                   7
# partners             6
# reports              6
# staff                6
# analyst              5
# provides             5
# perform              4
# support              4
# project              4
# remote               4
# may                  4
# knowledge            4
# annual               4
# that                 4
# regulations          4
# pri                  4
# match                4
# data                 3
# including            3
# this                 3
# all                  3
# budgetary            3
# costs                3
# monthly              3
